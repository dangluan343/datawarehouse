# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

import pyart

# %%
file_data = "../python/NHB230601000008.rawlgzv"

#######################################
# We can use the **pyart.io.read_nexrad_archive** module to access our data, passing in the filepath.

radar = pyart.io.read_sigmet(file_data)

#######################################
# Let's take a look at a summary of what fields are available.

# %%
fig = plt.figure(figsize=(12, 4))
display = pyart.graph.RadarMapDisplay(radar)

ax = plt.subplot(121, projection=ccrs.PlateCarree())

display.plot_ppi_map(
    "reflectivity",
    sweep=0,
    ax=ax,
    colorbar_label="Equivalent Relectivity ($Z_{e}$) \n (dBZ)",
    vmin=-20,
    vmax=60,
)
# Out:
# /opt/miniconda3/envs/pyart_env/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/110m_physical/ne_110m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /opt/miniconda3/envs/pyart_env/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_admin_1_states_provinces_lines.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
